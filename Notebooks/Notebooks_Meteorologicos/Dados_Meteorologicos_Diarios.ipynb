# %% [markdown]
# # Dados Metereológicos Diários

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dt

# %% [markdown]
# ### Construção de um dataframe com as colunas que representam as variáveis

# %%
#caminho do arquivo csv

file_path = Path(
    '../../Dados/Dados-Metereologicos/Horarios/' +\
     'dados_A320_H_A_2008-01-01_2013-12-31.csv'
     ) 

#importando o arquivo csv como um Dataframe

df = pd.read_csv(file_path, 
                 header=9, #linha do cabeçalho
                 sep=';',  #separador
                 usecols= #colunas
                 ['Data Medicao', 
                  'Hora Medicao', 
                  'PRECIPITACAO TOTAL, HORARIO(mm)',
                  'RADIACAO GLOBAL(Kj/m²)',
                  'TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)',
                  'TEMPERATURA MINIMA NA HORA ANT. (AUT)(°C)',
                  'TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)',
                  'VENTO, RAJADA MAXIMA(m/s)',
                  'VENTO, VELOCIDADE HORARIA(m/s)' ]
                 )
df.head()
# Out:
#   Data Medicao  Hora Medicao PRECIPITACAO TOTAL, HORARIO(mm)  \
# 0   2008-01-01             0                               0
# 1   2008-01-01           100                               0
# 2   2008-01-01           200                               0
# 3   2008-01-01           300                               0
# 4   2008-01-01           400                               0
#
#   RADIACAO GLOBAL(Kj/m²) TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)  \
# 0                  -3,54                                        25,9
# 1                  -3,54                                        25,7
# 2                  -3,54                                        25,7
# 3                  -3,54                                        25,5
# 4                  -3,54                                        25,4
#
#   TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)  \
# 0                                      26,1
# 1                                        26
# ...

# %% [markdown]
# No momento de importação o pandas reconheceu a hora de medição como número inteiro, por isso é necessário ajustar as horas de medição para se tornarem um padrão reconhecido pelo datetime

# %%
#ajustando as horas de medição para se tornarem um padrão reconhecido pelo datetime

df['Hora Medicao'] = (df['Hora Medicao']//100).astype(str)+':'+'00' 
df.head()
# Out:
#   Data Medicao Hora Medicao PRECIPITACAO TOTAL, HORARIO(mm)  \
# 0   2008-01-01         0:00                               0
# 1   2008-01-01         1:00                               0
# 2   2008-01-01         2:00                               0
# 3   2008-01-01         3:00                               0
# 4   2008-01-01         4:00                               0
#
#   RADIACAO GLOBAL(Kj/m²) TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)  \
# 0                  -3,54                                        25,9
# 1                  -3,54                                        25,7
# 2                  -3,54                                        25,7
# 3                  -3,54                                        25,5
# 4                  -3,54                                        25,4
#
#   TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)  \
# 0                                      26,1
# 1                                        26
# 2                                      25,9
# ...

# %%
#concatenando a hora com a data de medição e retirando a coluna das horas

df['Data Medicao'] = df['Data Medicao'] + ' ' + df['Hora Medicao'].astype(str)
df.drop('Hora Medicao', axis=1, inplace=True)
df.head()
# Out:
#       Data Medicao PRECIPITACAO TOTAL, HORARIO(mm) RADIACAO GLOBAL(Kj/m²)  \
# 0  2008-01-01 0:00                               0                  -3,54
# 1  2008-01-01 1:00                               0                  -3,54
# 2  2008-01-01 2:00                               0                  -3,54
# 3  2008-01-01 3:00                               0                  -3,54
# 4  2008-01-01 4:00                               0                  -3,54
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)  \
# 0                                        25,9
# 1                                        25,7
# 2                                        25,7
# 3                                        25,5
# 4                                        25,4
#
#   TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)  \
# 0                                      26,1
# 1                                        26
# 2                                      25,9
# 3                                      25,7
# ...

# %% [markdown]
# A coluna "Data Medicao" é composta por strings, então há a necessidade de transformar para Datetime e logo após transformar essa coluna, em uma coluna de índices

# %%
#transformando os valores da coluna em datetime

df['Data Medicao'] = pd.to_datetime(df['Data Medicao'])
df.head()
# Out:
#          Data Medicao PRECIPITACAO TOTAL, HORARIO(mm) RADIACAO GLOBAL(Kj/m²)  \
# 0 2008-01-01 00:00:00                               0                  -3,54
# 1 2008-01-01 01:00:00                               0                  -3,54
# 2 2008-01-01 02:00:00                               0                  -3,54
# 3 2008-01-01 03:00:00                               0                  -3,54
# 4 2008-01-01 04:00:00                               0                  -3,54
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)  \
# 0                                        25,9
# 1                                        25,7
# 2                                        25,7
# 3                                        25,5
# 4                                        25,4
#
#   TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)  \
# 0                                      26,1
# 1                                        26
# 2                                      25,9
# ...

# %%
#transformando a coluna das datas nos índices do dataframe

df.set_index('Data Medicao', inplace=True)
df.head()
# Out:
#                     PRECIPITACAO TOTAL, HORARIO(mm) RADIACAO GLOBAL(Kj/m²)  \
# Data Medicao
# 2008-01-01 00:00:00                               0                  -3,54
# 2008-01-01 01:00:00                               0                  -3,54
# 2008-01-01 02:00:00                               0                  -3,54
# 2008-01-01 03:00:00                               0                  -3,54
# 2008-01-01 04:00:00                               0                  -3,54
#
#                     TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)  \
# Data Medicao
# 2008-01-01 00:00:00                                        25,9
# 2008-01-01 01:00:00                                        25,7
# 2008-01-01 02:00:00                                        25,7
# 2008-01-01 03:00:00                                        25,5
# 2008-01-01 04:00:00                                        25,4
#
#                     TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)  \
# Data Medicao
# ...

# %% [markdown]
# Podemos ainda perceber que apesar de estarem representando valores numéricos cada célula é uma string, que utiliza vírgula para representar os número racionais. Porém é necessário que utilizemos float para realizar os plots e para transformar strings em floats é necessário que sejam utilizados pontos ao invés de vírgulas.

# %%
#transformando os dados de string para float

for coluna in df.columns:
    df[coluna] = df[coluna].str.replace(',','.').astype(float)

df.head()
# Out:
#                      PRECIPITACAO TOTAL, HORARIO(mm)  RADIACAO GLOBAL(Kj/m²)  \
# Data Medicao
# 2008-01-01 00:00:00                              0.0                   -3.54
# 2008-01-01 01:00:00                              0.0                   -3.54
# 2008-01-01 02:00:00                              0.0                   -3.54
# 2008-01-01 03:00:00                              0.0                   -3.54
# 2008-01-01 04:00:00                              0.0                   -3.54
#
#                      TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)  \
# Data Medicao
# 2008-01-01 00:00:00                                         25.9
# 2008-01-01 01:00:00                                         25.7
# 2008-01-01 02:00:00                                         25.7
# 2008-01-01 03:00:00                                         25.5
# 2008-01-01 04:00:00                                         25.4
#
#                      TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)  \
# Data Medicao
# ...

# %% [markdown]
# ### Divisão em dataframes para cada variável contendo os dados diários
#
# Nessa próxima parte do código o dataframe é dividido entre dataframes menores, contendo agora dados diários que envolvem, cada um, exclusivamente as variáveis de:
#
#     - Temperatura;
#     - Chuva;
#     - Vento;
#     - Radiação Solar.

# %% [markdown]
# #### Temperatura

# %%
df_temp = pd.DataFrame(columns=
                       ['TEMPERATURA MÉDIA DO AR DIARIA(°C)',
                        'TEMPERATURA MINIMA DIARIA (°C)',
                        'TEMPERATURA MAXIMA DIARIA (°C)'
                           ]
                       )

#A temperatura do ar diária será a média das temperaturas horárias

df_temp['TEMPERATURA MÉDIA DO AR DIARIA(°C)'] =\
    df['TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)'].resample('D').mean()

#A temperatura mínima diária será a menor temperatura das mínimas temperaturas horárias

df_temp['TEMPERATURA MINIMA DIARIA (°C)'] =\
    df['TEMPERATURA MINIMA NA HORA ANT. (AUT)(°C)'].resample('D').min()

#A temperatura máxima diária será a maior temperatura das máximas temperaturas horárias

df_temp['TEMPERATURA MAXIMA DIARIA (°C)'] =\
    df['TEMPERATURA MAXIMA NA HORA ANT. (AUT)(°C)'].resample('D').max()

df_temp.head()
# Out:
#               TEMPERATURA MÉDIA DO AR DIARIA(°C)  \
# Data Medicao
# 2008-01-01                             26.916667
# 2008-01-02                             27.045833
# 2008-01-03                             27.166667
# 2008-01-04                             27.379167
# 2008-01-05                             27.254167
#
#               TEMPERATURA MINIMA DIARIA (°C)  TEMPERATURA MAXIMA DIARIA (°C)
# Data Medicao
# 2008-01-01                              23.1                            30.7
# 2008-01-02                              25.1                            30.6
# 2008-01-03                              24.4                            30.7
# 2008-01-04                              25.8                            30.4
# 2008-01-05                              25.5                            30.4

# %% [markdown]
# #### Chuvas

# %%
#Criando o dataframe dos índices de chuva com o nome da coluna desejada
df_chuva = pd.DataFrame(columns=['PRECIPITACAO TOTAL, DIARIA(mm)'])

#A coluna Precipitação Total diária é a soma das precipitações horárias
df_chuva['PRECIPITACAO TOTAL, DIARIA(mm)'] = df['PRECIPITACAO TOTAL, HORARIO(mm)'].resample('D').sum()
df_chuva.head()
# Out:
#               PRECIPITACAO TOTAL, DIARIA(mm)
# Data Medicao
# 2008-01-01                               0.0
# 2008-01-02                               0.0
# 2008-01-03                               0.0
# 2008-01-04                               0.2
# 2008-01-05                               0.0

# %% [markdown]
# #### Vento

# %%
#Criando o dataframe das velocidades do vento com o nome da coluna desejada
df_vento = pd.DataFrame(columns=
                        ['VELOCIDADE MÉDIA DIÁRIA DO VENTO (m/s)',
                         'RAJADA MAXIMA DIARIA DO VENTO (m/s)']
                        )

#A velocidade diária do vento será a média das velocidades horárias
df_vento['VELOCIDADE MÉDIA DIÁRIA DO VENTO (m/s)' ] =\
    df['VENTO, VELOCIDADE HORARIA(m/s)'].resample('D').mean()

#A rajada máxima diária será a máxima rajada horária
df_vento['RAJADA MAXIMA DIARIA DO VENTO (m/s)'] =\
    df['VENTO, RAJADA MAXIMA(m/s)'].resample('D').max()

df_vento.head()
# Out:
#               VELOCIDADE MÉDIA DIÁRIA DO VENTO (m/s)  \
# Data Medicao
# 2008-01-01                                  2.812500
# 2008-01-02                                  2.770833
# 2008-01-03                                  3.670833
# 2008-01-04                                  3.300000
# 2008-01-05                                  2.841667
#
#               RAJADA MAXIMA DIARIA DO VENTO (m/s)
# Data Medicao
# 2008-01-01                                   10.8
# 2008-01-02                                    8.8
# 2008-01-03                                   11.4
# 2008-01-04                                   11.5
# 2008-01-05                                   10.2

# %% [markdown]
# #### Radiação Solar

# %%
df_rads = pd.DataFrame(columns=['RADIACAO SOLAR MÉDIA DIÁRIA (Kj/m²)',
                                'RADIACAO SOLAR MÁXIMA DIÁRIA (Kj/m²)'])

#A radiação solar diária média será a média das radiações soláres horárias
df_rads['RADIACAO SOLAR MÉDIA DIÁRIA (Kj/m²)'] =\
    df['RADIACAO GLOBAL(Kj/m²)'].resample('D').mean()

#A radiação solar diária máxima será a máxima a radiação solar diária
df_rads['RADIACAO SOLAR MÁXIMA DIÁRIA (Kj/m²)'] =\
    df['RADIACAO GLOBAL(Kj/m²)'].resample('D').max()

df_rads.head()
# Out:
#               RADIACAO SOLAR MÉDIA DIÁRIA (Kj/m²)  \
# Data Medicao
# 2008-01-01                            1122.721625
# 2008-01-02                             998.177125
# 2008-01-03                            1033.692875
# 2008-01-04                             899.273917
# 2008-01-05                            1005.617375
#
#               RADIACAO SOLAR MÁXIMA DIÁRIA (Kj/m²)
# Data Medicao
# 2008-01-01                                3610.771
# 2008-01-02                                3167.936
# 2008-01-03                                3429.173
# 2008-01-04                                3115.432
# 2008-01-05                                3456.494

# %% [markdown]
# ### Divisão dos dataframes diários para cada ano

# %%
#dividindo os dados da temperatura por anos
df_temp_08 = df_temp.loc[df_temp.index.year == 2008]
df_temp_09 = df_temp.loc[df_temp.index.year == 2009]
df_temp_10 = df_temp.loc[df_temp.index.year == 2010]
df_temp_11 = df_temp.loc[df_temp.index.year == 2011]
df_temp_12 = df_temp.loc[df_temp.index.year == 2012]
df_temp_13 = df_temp.loc[df_temp.index.year == 2013]


#dividindo os dados da chuva por anos
df_chuva_08 = df_chuva.loc[df_chuva.index.year == 2008]
df_chuva_09 = df_chuva.loc[df_chuva.index.year == 2009]
df_chuva_10 = df_chuva.loc[df_chuva.index.year == 2010]
df_chuva_11 = df_chuva.loc[df_chuva.index.year == 2011]
df_chuva_12 = df_chuva.loc[df_chuva.index.year == 2012]
df_chuva_13 = df_chuva.loc[df_chuva.index.year == 2013]


#dividindo os dados do vento por anos
df_vento_08 = df_vento.loc[df_vento.index.year == 2008]
df_vento_09 = df_vento.loc[df_vento.index.year == 2009]
df_vento_10 = df_vento.loc[df_vento.index.year == 2010]
df_vento_11 = df_vento.loc[df_vento.index.year == 2011]
df_vento_12 = df_vento.loc[df_vento.index.year == 2012]
df_vento_13 = df_vento.loc[df_vento.index.year == 2013]


#dividindo os dados da radiação solar por anos
df_rads_08 = df_rads.loc[df_rads.index.year == 2008]
df_rads_09 = df_rads.loc[df_rads.index.year == 2009]
df_rads_10 = df_rads.loc[df_rads.index.year == 2010]
df_rads_11 = df_rads.loc[df_rads.index.year == 2011]
df_rads_12 = df_rads.loc[df_rads.index.year == 2012]
df_rads_13 = df_rads.loc[df_rads.index.year == 2013]

# %% [markdown]
# ### Gráficos por variável

# %%
# Configurações globais dos gráficos
label_x = 'dias'
# date = mdates.MonthLocator()   
# days = mdates.DayLocator()  
fmt = dt.DateFormatter('%d-%m')

# %%
#Gráfico das temperaturas

plt.style.use('seaborn-dark-palette')

fig1, f1_axes = plt.subplots(ncols=2, nrows=3, constrained_layout=True, figsize=(20,15))

fig1.suptitle('Temperaturas diárias dos anos de 2008 a 2013',size=30)


#definindo uma lista com o nome de variáveis para facilitar possíveis alterações
col_names_temp = ['TEMPERATURA MAXIMA DIARIA (°C)',
                  'TEMPERATURA MÉDIA DO AR DIARIA(°C)',
                  'TEMPERATURA MINIMA DIARIA (°C)']

#definindo variáveis sendo as labels dos eixos 
label_y_temp = 'TEMPERATURA (°C)'

# plotando os dados de temperatura 
for nome_coluna in col_names_temp:
 
    
    # plot 1
    f1_axes[0,0].plot(df_temp_08[nome_coluna], label = nome_coluna)

    # plot 2
    f1_axes[0,1].plot(df_temp_09[nome_coluna], label = nome_coluna)
    
    # plot 3
    f1_axes[1,0].plot(df_temp_10[nome_coluna], label = nome_coluna)
    
    #plot 4
    f1_axes[1,1].plot(df_temp_11[nome_coluna], label = nome_coluna)
    
    #plot 5
    f1_axes[2,0].plot(df_temp_12[nome_coluna], label = nome_coluna)
    
    #plot 6
    f1_axes[2,1].plot(df_temp_13[nome_coluna], label = nome_coluna)

ano_inicial = 2008
for i in range(3):
    for j in range(2):
        f1_axes[i,j].set_title(f'Ano de {ano_inicial}', size=25)
        
        #f1_axes[i,j].xaxis.set_major_locator(df_temp.index)
        f1_axes[i,j].xaxis.set_major_formatter(fmt)
        #f1_axes[i,j].xaxis.set_minor_locator(days)
        
        f1_axes[i,j].set_xlabel(label_x, size=20)
        f1_axes[i,j].set_ylabel(label_y_temp, size=16)

        f1_axes[i,j].tick_params(axis='x', labelsize=16, rotation=40)
        f1_axes[i,j].tick_params(axis='y', labelsize=16)

        f1_axes[i,j].grid()
        f1_axes[i,j].legend()
        ano_inicial = ano_inicial + 1
        
#salvando a figura na pasta /Plots/Diarios com o nome de "Temperatura.png"  
path_plot_temp = Path('./Plots/Diarios/Temperatura.png') #utilizando essa biblioteca para que o código funcione em windows
fig1.savefig(path_plot_temp, format='png')

# %% [markdown]
# #### Nos dados referentes a temperatura podemos notar alguns dados faltantes em 2010 e fica explícito que em quase todo o ano de 2012 ocorreu algum problema na mensuração. Ainda, em 2013 conseguimos reparar alguns dados faltantes próximo ao mês 07 (Número exato do dia verificado ao fim do Notebook). Verificaremos ao longo dos outros gráficos que esse é um comportamento se repete, ou seja, não é um problema unicamente na mensuração dessa variável, mas sim em todas.

# %%
#Gráfico das chuvas

fig2, f2_axes = plt.subplots(nrows=3, ncols=2, constrained_layout=True, figsize=(20,15))

fig2.suptitle('Chuvas diárias ao longo dos anos de 2008 a 2013',size=30)

#definindo uma variável que armazene o nome da coluna desejada  
col_name_chuva = 'PRECIPITACAO TOTAL, DIARIA(mm)'

#definindo o label do eixo y:
label_y_chuva = 'PRECIPITAÇÃO (mm)'

#primeiro plot
f2_axes[0,0].plot(df_chuva_08[col_name_chuva], label = col_name_chuva)

#segundo plot
f2_axes[0,1].plot(df_chuva_09[col_name_chuva], label = col_name_chuva)

#terceiro plot
f2_axes[1,0].plot(df_chuva_10[col_name_chuva], label = col_name_chuva)

#quarto plot
f2_axes[1,1].plot(df_chuva_11[col_name_chuva], label = col_name_chuva)

#quinto plot
f2_axes[2,0].plot(df_chuva_12[col_name_chuva], label = col_name_chuva)

#sexto plot
f2_axes[2,1].plot(df_chuva_13[col_name_chuva], label = col_name_chuva)

ano_inicial = 2008
for i in range(3):
    for j in range(2):
        f2_axes[i,j].set_title(f'Ano de {ano_inicial}', size=25)
        f2_axes[i,j].xaxis.set_major_formatter(fmt)
        #f2_axes[i,j].xaxis.set_minor_locator(days)
        
        f2_axes[i,j].set_xlabel(label_x, size=20)
        f2_axes[i,j].set_ylabel(label_y_chuva, size=16)

        f2_axes[i,j].tick_params(axis='x', labelsize=16, rotation=40)
        f2_axes[i,j].tick_params(axis='y', labelsize=16)

        f2_axes[i,j].grid()
        f2_axes[i,j].legend()
        ano_inicial = ano_inicial + 1 
        
#salvando a figura na pasta /Plots/Diarios com o nome de "Chuvas.png"  
path_plot_temp = Path('./Plots/Diarios/Chuvas.png') #utilizando essa biblioteca para que o código funcione em windows
fig2.savefig(path_plot_temp, format='png')

# %% [markdown]
# #### Os anos de 2012, 2010 e 2013 dos gráficos de precipitação explicitam que nos intervalos em que as outras variáveis apresentam dados faltantes, os dados registram precipitação de 0mm. O que torna mais complicado de analisar, visto que podem existir dias em que a precipitação foi de 0mm e outros em que na verdade foram ocasionados de falhas na medição.

# %%
#Gráficos da velocidade do vento
fig3, f3_axes = plt.subplots(nrows=3, ncols=2, constrained_layout=True, figsize=(20,15))

fig3.suptitle('Velocidade diária dos ventos ao longo dos anos de 2008 a 2013',size=30)

#salvando em uma variável o nome das colunas do df vento
col_names_vento = ['VELOCIDADE MÉDIA DIÁRIA DO VENTO (m/s)', 
                   'RAJADA MAXIMA DIARIA DO VENTO (m/s)']

#definindo o label do eixo y:
label_y_vento = 'VELOCIDADE (m/s)'

#realizando o plot
for nome_coluna in col_names_vento:
    #primeiro plot
    f3_axes[0,0].plot(df_vento_08[nome_coluna], label = nome_coluna)
    
    #segundo plot
    f3_axes[0,1].plot(df_vento_09[nome_coluna], label = nome_coluna)
    
    #terceiro plot
    f3_axes[1,0].plot(df_vento_10[nome_coluna], label = nome_coluna)
    
    #quarto plot
    f3_axes[1,1].plot(df_vento_11[nome_coluna], label = nome_coluna)
    
    #quinto plot
    f3_axes[2,0].plot(df_vento_12[nome_coluna], label =nome_coluna)
    
    #sexto plot
    f3_axes[2,1].plot(df_vento_13[nome_coluna], label = nome_coluna)

#configurando os gráficos
ano_inicial = 2008
for i in range(3):
    for j in range(2):
        f3_axes[i,j].set_title(f'Ano de {ano_inicial}', size=25)
        
        #f3_axes[i,j].xaxis.set_major_locator(date)
        f3_axes[i,j].xaxis.set_major_formatter(fmt)
        #f3_axes[i,j].xaxis.set_minor_locator(days)
        
        f3_axes[i,j].set_xlabel(label_x, size=20)
        f3_axes[i,j].set_ylabel(label_y_vento, size=16)

        f3_axes[i,j].tick_params(axis='x', labelsize=16, rotation=40)
        f3_axes[i,j].tick_params(axis='y', labelsize=16)

        f3_axes[i,j].grid()
        f3_axes[i,j].legend()
        ano_inicial = ano_inicial + 1 

#salvando a figura na pasta /Plots/Diarios com o nome de "Ventos.png"  
path_plot_temp = Path('./Plots/Diarios/Ventos.png') #utilizando essa biblioteca para que o código funcione em windows
fig3.savefig(path_plot_temp, format='png')

# %% [markdown]
# #### Podemos verificar que os dados faltantes da velocidade do vento estão em intervalos iguais ou muito próximos dos dados faltantes da variável temperatura

# %%
#Gráficos da radiação solar 
fig4, f4_axes = plt.subplots(nrows=3, ncols=2, constrained_layout=True, figsize=(20,15))

fig4.suptitle('Radiação solar diária nos anos de 2008 a 2013',size=30)

#salvando em uma variável o nome das colunas do df vento
col_names_rads = ['RADIACAO SOLAR MÉDIA DIÁRIA (Kj/m²)',
                  'RADIACAO SOLAR MÁXIMA DIÁRIA (Kj/m²)']

#definindo o label do eixo y:
label_y_rads = 'Radiação Solar (Kj/m)'
                
for nome_coluna in col_names_rads:
    #primeiro plot
    f4_axes[0,0].plot(df_rads_08[nome_coluna], label = nome_coluna)

    #segundo plot
    f4_axes[0,1].plot(df_rads_09[nome_coluna], label = nome_coluna)

    #terceiro plot
    f4_axes[1,0].plot(df_rads_10[nome_coluna], label = nome_coluna)

    #quarto plot
    f4_axes[1,1].plot(df_rads_11[nome_coluna], label = nome_coluna)

    #quinto plot
    f4_axes[2,0].plot(df_rads_12[nome_coluna], label = nome_coluna)

    #sexto plot
    f4_axes[2,1].plot(df_rads_13[nome_coluna], label = nome_coluna)

#configurando os gráficos
ano_inicial = 2008
for i in range(3):
    for j in range(2):
        f4_axes[i,j].set_title(f'Ano de {ano_inicial}', size=25)
        
        #f4_axes[i,j].xaxis.set_major_locator(date)
        f4_axes[i,j].xaxis.set_major_formatter(fmt)
        #f4_axes[i,j].xaxis.set_minor_locator(days)
    
        f4_axes[i,j].set_xlabel(label_x, size=20)
        f4_axes[i,j].set_ylabel(label_y_rads, size=16)

        f4_axes[i,j].tick_params(axis='x', labelsize=16, rotation=40)
        f4_axes[i,j].tick_params(axis='y', labelsize=16)

        f4_axes[i,j].grid()
        f4_axes[i,j].legend()
        ano_inicial = ano_inicial + 1 
        
#salvando a figura na pasta /Plots/Diarios com o nome de "Radiacao.png"  
path_plot_temp = Path('./Plots/Diarios/Radiacao.png') #utilizando essa biblioteca para que o código funcione em windows
fig4.savefig(path_plot_temp, format='png')

# %% [markdown]
# #### Podemos verificar que além dos dados faltantes nos intervalos mencionados em outras variáveis. A radiação apresenta um comportamento atípico no ano de 2010, entre o mês 06 e mês 10.

# %% [markdown]
# ### Avaliando o intervalo de dias que apresentam uma quantidade explícita de dados faltantes
#
# ##### Nessa parte, é feito uma tabela com todos os dados diários do ano. As colunas e linhas que existem valores são preenchidas com False, do contrário é retornado um True, afirmando que existe dados faltantes.
#
# ##### No caso dos dados pluviométricos foi visto graficamente que os dados faltantes foram representados como zeros, então alguns "True" da tabela na coluna pluviométrica não necessariamente representam dados faltantes, mas sim zeros verdadeiros.

# %% [markdown]
# #### Avaliando o intervalo de dias de 2010 que apresentam incongruência nos dados
#
# ##### É possível identificar alguns valores faltantes em 2010 mas não muitos.

# %%
#retornando um dataframe com False nas colunas que possuem valores e True nas colunas que não possuem
temp_null_10 = df_temp_10.isnull()
vento_null_10 = df_vento_10.isnull()
rad_null_10 = df_rads_10.isnull()
#No caso dos dados de precipitação total vemos que o problema ocorre porém existem valores iguais a 0 ao invés de null
chuvas_null_10 = df_chuva_10['PRECIPITACAO TOTAL, DIARIA(mm)'] == 0.0

#concatenando e formando um único dataframe.
all_null_10 = pd.concat([temp_null_10,chuvas_null_10, vento_null_10, rad_null_10], axis=1) 

#apresentando o dataframe na fatia em que existem dados faltantes
display(all_null_10.iloc[180:230])
# Out:
#               TEMPERATURA MÉDIA DO AR DIARIA(°C)  \
# Data Medicao
# 2010-06-30                                 False
# 2010-07-01                                  True
# 2010-07-02                                 False
# 2010-07-03                                 False
# 2010-07-04                                 False
# 2010-07-05                                 False
# 2010-07-06                                 False
# 2010-07-07                                 False
# 2010-07-08                                 False
# 2010-07-09                                  True
# 2010-07-10                                 False
# 2010-07-11                                 False
# 2010-07-12                                 False
# 2010-07-13                                 False
# 2010-07-14                                 False
# 2010-07-15                                 False
# 2010-07-16                                  True
# 2010-07-17                                  True
# ...

# %% [markdown]
# #### Avaliando o intervalo de dias de 2012 que apresentam incongruência nos dados
#
# ##### É possível observar através disso que a partir do dia 14/02/2012 até o dia 12/10/2012 os dados são inconsistentes.

# %%
#retornando um dataframe com False nas colunas que possuem valores e True nas colunas que não possuem
temp_null_12 = df_temp_12.isnull()
vento_null_12 = df_vento_12.isnull()
rad_null_12 = df_rads_12.isnull()
    
#No caso dos dados de precipitação total vemos que o problema ocorre porém existem valores iguais a 0 ao invés de null
chuvas_null_12 = df_chuva_12['PRECIPITACAO TOTAL, DIARIA(mm)'] == 0.0

#concatenando e formando um único dataframe.

all_null_12 = pd.concat([temp_null_12,chuvas_null_12, vento_null_12, rad_null_12], axis=1) 

#apresentando o dataframe na posição aonde começam os dados faltantes
display(all_null_12.iloc[35:55])
#apresentando o dataframe na posição aonde terminam os dados faltantes
display(all_null_12.iloc[335:366])
# Out:
#               TEMPERATURA MÉDIA DO AR DIARIA(°C)  \
# Data Medicao
# 2012-02-05                                 False
# 2012-02-06                                 False
# 2012-02-07                                 False
# 2012-02-08                                 False
# 2012-02-09                                 False
# 2012-02-10                                 False
# 2012-02-11                                 False
# 2012-02-12                                 False
# 2012-02-13                                 False
# 2012-02-14                                  True
# 2012-02-15                                  True
# 2012-02-16                                  True
# 2012-02-17                                  True
# 2012-02-18                                  True
# 2012-02-19                                  True
# 2012-02-20                                  True
# 2012-02-21                                  True
# 2012-02-22                                  True
# ...

# %% [markdown]
# #### Avaliando o intervalo de dias de 2013 que apresenta incongruência nos dados
# ##### Podemos verificar que os dados de 2013 apresentam inconsistência no dia 19/06/2013 até o dia 15/07/2013

# %%
#retornando um dataframe com False nas colunas que possuem valores e True nas colunas que não possuem
temp_null_13 = df_temp_13.isnull()
vento_null_13 = df_vento_13.isnull()
rad_null_13 = df_rads_13.isnull()

#No caso dos dados de precipitação total vemos que o problema ocorre porém existem valores iguais a 0 ao invés de null
chuvas_null_13 = df_chuva_13['PRECIPITACAO TOTAL, DIARIA(mm)'] == 0.0

#concatenando e formando um único dataframe.
all_null_13 = pd.concat([temp_null_13,chuvas_null_13, vento_null_13, rad_null_13], axis=1) 

#apresentando o dataframe na posição aonde começam os dados faltantes
display(all_null_13.iloc[160:180])
#apresentando todo o dataframe na posição aonde terminam os dados faltantes
display(all_null_13.iloc[185:205])
# Out:
#               TEMPERATURA MÉDIA DO AR DIARIA(°C)  \
# Data Medicao
# 2013-06-10                                 False
# 2013-06-11                                 False
# 2013-06-12                                 False
# 2013-06-13                                 False
# 2013-06-14                                 False
# 2013-06-15                                 False
# 2013-06-16                                 False
# 2013-06-17                                 False
# 2013-06-18                                 False
# 2013-06-19                                  True
# 2013-06-20                                  True
# 2013-06-21                                  True
# 2013-06-22                                  True
# 2013-06-23                                  True
# 2013-06-24                                  True
# 2013-06-25                                  True
# 2013-06-26                                  True
# 2013-06-27                                  True
# ...

# %% [markdown]
# #### Ao fim, desejo agora salvar em um arquivo csv o dataframe de radiação para que eu possa usa-lo para construir os dados semanais.

# %%
path_dados = Path('../../Dados/Dados-Metereologicos/Diarios/dados_radiacao.csv')
df_rads.to_csv(path_dados)
